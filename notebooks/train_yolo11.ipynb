# %%
from google.colab import drive
drive.mount('/content/drive')

# Install YOLO11
# !pip install ultralytics

# !cp /content/drive/MyDrive/DroneProject/dataset.zip /content/
# !unzip -q /content/dataset.zip -d /content/datasets/

from ultralytics import YOLO

model = YOLO('yolo11n.pt')

# Train
# project: defines the root save folder
# name: defines the subfolder for this specific run
model.train(
    data='/content/data.yaml', 
    epochs=100, 
    imgsz=640, 
    project='/content/drive/MyDrive/DroneProject/runs', 
    name='rgb_ir_run1'
)
